# %%
import numpy as np
import pandas as pd

# %%
Mall_customer = pd.read_csv('Mall_Customers.csv')
Mall_customer

# %%
# Count
Mall_customer.count()

# %%
Mall_customer.describe()

# %%
Mall_customer.drop(['CustomerID'], axis = 1, inplace = True)

# %%
Mall_customer

# %%
# Splitting into train_set and test_set

Mall = Mall_customer.head(6)
Mall

# %%
# Splitting

X = Mall[['Annual Income (k$)', 'Spending Score (1-100)']]
Y = Mall[['Age', 'Annual Income (k$)']]

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(X, Y)
plt.show()

# %%
# Okay lemme do it like this

from sklearn.cross_validation import train_test_split
train_X, train_y, test_X, test_y =
