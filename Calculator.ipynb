# %%
print('hello world')

# %%
print("CALCULATOR.PY")
print("select an operation to perform :")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

operation=input("select an operator (1/2/3/4):")

if operation == "1":
  value1 = int(input("Enter first value:"))
  value2 = int(input("Enter second value:"))
  print("The sum is " + str(int(value1 + int(value2)))
elif operation == "2":
  value1 = int(input("Enter first value: "))
  value2 = int(input("Enter second value: "))
  print("The difference is " + str(int(value1 - int(value2)))
elif operation == "3":
  value1 = int(input("Enter first value:"))
  value2 = int(input("Enter second value:"))
  print("The total is " + str(int(value1 * int(value2)))
else:
  value1 = int(input("Enter first value:"))
  value2 = int(input("Enter second value:"))
  print("The total is " + str(value1 / int(value2)))

# %%
print("Hello")
