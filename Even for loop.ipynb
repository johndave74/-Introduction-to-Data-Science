# %%
print("even numbers:")
for even_numbers in range(0,11,2):
  print(even_numbers)

# %%
print('odd numbers:')
for odd_numbers in range(1,12,2):
  print(odd_numbers)

# %%
print('even numbers')
i=0
while i<4:
  print(i)
  i=i+1

# %%
# define functions
def even_numbers

  print(i)
  i=i+1
