# %%
# my biography

bio_data = {"First name": "John", "second name": 'David', "institution": "LAUTECH","Department": "Biochemistry", "Faculty": "Basic Medical Science"}

bio_data

# %%
# my biography
my_bio = {"surname":"David", "First name":"John", "Last name":"Oluwasemilore", "Occupation":"Student", "Institution": "Ladoke Akintola University Of Technology", "Department":"Biochemistry", "Faculty":"Basic Medical Science", }
my_bio
